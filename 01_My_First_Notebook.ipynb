# %% [markdown]
# #### Intro to Machine Learning with Python
# - by Rahul

# %%
print('I Like Python')
# Out:
# I Like Python

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
a + b
# Out:
# 30

# %%
a + b
a - b
# Out:
# -10

# %%
print(a + b)
print(a - b)
# Out:
# 30
# -10
